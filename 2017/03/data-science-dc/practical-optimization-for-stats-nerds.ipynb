# %% [markdown]
# # Practical Optimization for Stats Nerds
#
# Ryan J. O'Neil
# Data Science DC
# March 20, 2017
#
# [ryanjoneil@gmail.com](mailto:ryanjoneil@gmail.com)
# [https://ryanjoneil.github.io](https://ryanjoneil.github.io)
# [@ryanjoneil](https://twitter.com/ryanjoneil)

# %% [markdown]
# ## Take-aways, in case you want to skip the talk
#
#
# * Many statistical techniques are based on some sort of optimization.

# %% [markdown]
# * Optimization has many other uses, such as solving decision models.

# %% [markdown]
# * Learning to structure problems you already know for optimization solvers is a great way to understand them!

# %% [markdown]
# ## Least Squares
#
# We observe noisy data from an unknown function. We want to infer that function.

# %% [markdown]
# But let's assume that, deep down, we actually know the function. That way we can generate noisy data and see if our techniques work right.
#
# #### Function:
# $$y = 3x^2 - 2x + 10 + \epsilon$$
#
# #### Noise:
# $$\epsilon \sim N\left(0, 25\right)$$

# %%
# Generate some random data.
import numpy as np
import random

# Sort the data so they're easier to plot later.
x = [random.uniform(-10, 10) for _ in range(500)]
x.sort()

y = []
for xi in x:
    eps = random.normalvariate(0, 25)
    yi = 3*xi**2 - 2*xi + 10 + eps
    y.append(yi)
    
x = np.array(x)
y = np.array(y)

# %%
from bokeh.charts import Scatter, output_notebook, show
output_notebook()

scatter = Scatter({'x': x, 'y': y}, width=750, height=400)
show(scatter)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d4838346-cf99-410c-b55a-eff62d586618">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="35eec0f9-590b-49e3-a978-40a2f9f21ed5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("35eec0f9-590b-49e3-a978-40a2f9f21ed5").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("35eec0f9-590b-49e3-a978-40a2f9f21ed5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '35eec0f9-590b-49e3-a978-40a2f9f21ed5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"80bb192f-3daf-48d8-a901-80ef6cb1ec95":{"roots":{"references":[{"attributes":{},"id":"465f845e-244b-4150-92be-e71321d919b8","type":"BasicTicker"},{"attributes":{"callback":null,"end":419.27720124257957,"start":-77.58308128095672},"id":"e52c3023-d9ea-4785-a08a-1a1a4e4dd3df","type":"Range1d"},{"attributes":{},"id":"ba2aa92c-daea-4e13-b369-28448148119b","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"279504af-4225-4f8e-b57a-e2e03e3f5ab0","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"207f50a0-1115-4b70-aaef-6eb4e9905023","subtype":"Chart","type":"Plot"},"ticker":{"id":"465f845e-244b-4150-92be-e71321d919b8","type":"BasicTicker"}},"id":"1b6eacd8-ad32-4531-b161-873ce4a1a4c0","type":"Grid"},{"attributes":{},"id":"fe379b66-a03b-4d5f-9557-656beb5bb9da","type":"BasicTicker"},{"attributes":{"callback":null,"end":11.867015732064658,"start":-11.98744418378032},"id":"e7a92cdf-2f84-45e2-ac8f-94dd83e0b741","type":"Range1d"},{"attributes":{"plot":null,"text":null},"id":"e6490032-54b7-4206-aaec-8b62967385e5","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"207f50a0-1115-4b70-aaef-6eb4e9905023","subtype":"Chart","type":"Plot"},"ticker":{"id":"fe379b66-a03b-4d5f-9557-656beb5bb9da","type":"BasicTicker"}},"id":"fceae3eb-7aa2-4a7a-acc5-b2b6121f9f7d","type":"Grid"},{"attributes":{},"id":"05eca364-dd00-435e-9e56-11eb87947341","type":"BasicTickFormatter"},{"attributes":{"axis_label":"y","formatter":{"id":"05eca364-dd00-435e-9e56-11eb87947341","type":"BasicTickFormatter"},"plot":{"id":"207f50a0-1115-4b70-aaef-6eb4e9905023","subtype":"Chart","type":"Plot"},"ticker":{"id":"fe379b66-a03b-4d5f-9557-656beb5bb9da","type":"BasicTicker"}},"id":"5bcdb99d-9fad-4c3f-a82f-b13767ac0139","type":"LinearAxis"},{"attributes":{"plot":{"id":"207f50a0-1115-4b70-aaef-6eb4e9905023","subtype":"Chart","type":"Plot"}},"id":"969dc4d7-f7e1-4c2f-9fe5-b05f5e3a47ed","type":"PanTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,n ...

# %% [markdown]
# ### Least Squares the way _you_ do it...
#
# ...assuming you use `scikit-learn` like every other sane Python programmer.

# %% [markdown]
# We looked at a chart of our data and decided to describe it with:
#
# * A quadratic term
# * A linear term
# * An offset

# %%
from sklearn.linear_model import LinearRegression

# Note: A is our feature matrix.
#       We intentionally add a "1" for the offset, instead of letting 
#       sklearn do that for us. This will make sense soon.

X = np.array([[xi**2, xi, 1] for xi in x])

lin = LinearRegression(fit_intercept=False)
lin.fit(X, y)

print(lin.coef_)
# Out:
# [ 3.01657041 -2.20803262  9.41616619]
# /Users/roneil/src/github.com/ryanjoneil/talks/2017/03/data-science-dc/lib/python3.6/site-packages/scipy/linalg/basic.py:884: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %%
from bokeh.charts import Line

# How'd we do?
y_hat = lin.predict(X)
show(Line({'x': x, 'y': y_hat}, x='x', y='y', width=750, height=400))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e6132905-9d07-42dd-9c9f-d451cbbaf7a4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e6132905-9d07-42dd-9c9f-d451cbbaf7a4").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e6132905-9d07-42dd-9c9f-d451cbbaf7a4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e6132905-9d07-42dd-9c9f-d451cbbaf7a4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1c782407-9c63-4659-9d69-023b6fc2cbe5":{"roots":{"references":[{"attributes":{},"id":"78eb3720-806a-43a7-aa32-20d8465c120a","type":"BasicTickFormatter"},{"attributes":{"axis_label":"x","formatter":{"id":"c999bad1-d0f7-48b9-a7ce-a206a9ca7358","type":"BasicTickFormatter"},"plot":{"id":"6d4652d4-90e4-4496-99c4-60ccf21ab9f0","subtype":"Chart","type":"Plot"},"ticker":{"id":"f825d93e-a6ff-4c31-bed6-883f16e82026","type":"BasicTicker"}},"id":"0f478fde-c123-42b4-bef8-151b1ab331fc","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"66b28dd5-8862-4020-93d6-961bb4fc0485","type":"PanTool"},{"id":"729b7de2-b0ab-4032-a1eb-4d5428274564","type":"WheelZoomTool"},{"id":"8343900c-ca56-4cf1-8b92-7e3436e71a53","type":"BoxZoomTool"},{"id":"f43717c0-5496-4a20-94b0-e7107a41af2c","type":"SaveTool"},{"id":"ea0d9a48-9b87-44bb-9888-af06751d3e20","type":"ResetTool"},{"id":"31a48ac3-c7b9-4916-988e-6f5d8431181d","type":"HelpTool"}]},"id":"a6df5b51-7d5c-4b1e-a4cd-36a9fcdea64a","type":"Toolbar"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":
# %% [markdown]
# ### Least Squares the way your _grandparents_ did it...
#
# ...with chalk and a slab of slate.

# %% [markdown]
# Construct a function to calculate the sum of squared residuals...
#
# $$
# \begin{align}
#     \text{min}\ f(\beta) & = \frac{1}{2} ||y - X \beta||^2 \\
#                          & \\
#                          & = \frac{1}{2} (y - X \beta)'(y - X \beta) \\
#                          & \\
#                          & = \frac{1}{2} y'y - y'X\beta + \frac{1}{2} \beta'X'X\beta \\
#                          & \\
#                          & = \frac{1}{2} y'y - y'X\beta + \frac{1}{2} \beta'X'X\beta \\
#                          & \\
# \end{align}
# $$

# %% [markdown]
# #### First Order Necessary Conditions
#
# ...and take its derivative to find a closed-form solution.
#
# $$\nabla f(\beta) = X'X\beta - y'X\beta = 0$$
# $$\beta = (X'X)^{-1}X'y$$

# %%
from numpy.linalg import inv

# beta = (X'X)^-1 * X * y
Xt = X.transpose()
pseudo_inv = inv(np.matmul(Xt, X))
beta = np.matmul(np.matmul(pseudo_inv, Xt), y)
print(beta)
# Out:
# [  2.97001072  -2.28578637  10.56301685]

# %%
# How'd grandpa and grandma do?
y_hat = [beta[0]*xi**2 + beta[1]*xi + beta[2] for xi in x]
show(Line({'x': x, 'y': y_hat}, x='x', y='y', width=750, height=400))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6bde0c47-9735-454f-81af-73812234048c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("6bde0c47-9735-454f-81af-73812234048c").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6bde0c47-9735-454f-81af-73812234048c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6bde0c47-9735-454f-81af-73812234048c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6b252068-8e01-4ca0-89c1-c607d58276d6":{"roots":{"references":[{"attributes":{"plot":{"id":"6052d543-c303-423b-94c4-56d39cac2525","subtype":"Chart","type":"Plot"}},"id":"efc999df-0bad-4a1d-b2b6-3bfd65ff6bec","type":"HelpTool"},{"attributes":{"plot":{"id":"6052d543-c303-423b-94c4-56d39cac2525","subtype":"Chart","type":"Plot"}},"id":"cb453d66-1228-4ed8-ad8b-bf95f4528193","type":"ResetTool"},{"attributes":{"plot":{"id":"6052d543-c303-423b-94c4-56d39cac2525","subtype":"Chart","type":"Plot"}},"id":"bdadbe9f-a16f-4b21-bbca-7fa97d362b09","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"6052d543-c303-423b-94c4-56d39cac2525","subtype":"Chart","type":"Plot"},"ticker":{"id":"1fdd7368-f171-4d3d-8d60-235e3c3f2ef5","type":"BasicTicker"}},"id":"f792fec8-d662-4206-a865-05ecdf47f266","type":"Grid"},{"attributes":{},"id":"24e999f0-2d40-4f50-b90a-26e295b87802","type":"ToolEvents"},{"attributes":{},"id":"1fdd7368-f171-4d3d-8d60-235e3c3f2ef5","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"400dfef6-ce41-43bb-b866-f4a65f90ffde","type":"BoxAnnotation"},{"attributes":{"axis_label":"y","formatter":{"id":"bb146c6c-e60d-4b77-9085-da5787d00d85","type":"BasicTickFormatter"},"plot":{"id":"6052d543-c303-423b-94c4-56d39cac2525","subtype":"Chart","type":"Plot"},"ticker":{"id":"ce4cbb1d-e542-4c78-87c7-ce1c17d4888b","type":"BasicTicker"}},"id":"4c2dcc81-5ba5-457c-a612-e520a660cc3a","type":"LinearAxis"},{"attributes":{"plot":{"id":"6052d543-c303-423b-94c4-56d39cac2525","subtype":"Chart","type":"Plot"}},"id":"3d918b77-753b-4a84-beff-948386e96494","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"6052d543-c303-423b-94c4-56d39cac2525","subtype":"Chart","type":"Plot"},"ticker":{"id":"ce4cbb1d-e542-4c78-87c7-ce1c17d4888b","type":"BasicTicker"}},"id":"39c19891-c643-4553-9e19-6f6125d3b41d","type":"Grid"},{"attributes":{"location":"top_left","plot":{"id":"6052d543-c303-423b-94c4-56d39cac2525","subtype":"Chart","type":"Plot"}},"id":"951fcc63-220c-4733-888b-1c930312d39d","type":"Legend"},{"attributes":{"callback":null,"end":11.915351831094826,"start":-11.951127453127349},"id":"0d588342-9ba7-415f-8824-308094a3f2d7","type":"Range1d"},{"attributes":{},"id":"ce4cbb1d-e542-4c78-87c7-ce1c17d4888b","type":"BasicTicker"},{"attributes":{"axis_label":"x","formatter":{"id":"178615ce-35c0-4a75-92d3-21ae0a7c0179","type":"BasicTickFormatter"},"plot":{"id":"6052d543-c303-423b-94c4-56d39cac2525","subtype":"Chart","type":"Plot"},"ticker":{"id":"1fdd7368-f171-4d3d-8d60-235e3c3f2ef5","type":"BasicTicker"}},"id":"771642b6-95d5-4aa6-bf11-44692f5eeadf","type":"LinearAxis"},{"attributes":{"plot":null,"text":null},"id":"f5e844cc-df6b-4f61-b923-5f023128c835","type":"Title"},{"attributes":{"line_color":{"value":"#f22c40"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"4d9b87cc-2124-45e2-8dcf-2b72f5b4b84c","type":"Line"},{"attributes":{"overlay":{"id":"400dfef6-ce41-43bb-b866-f4a65f90ffde","type":"BoxAnnotation"},"plot":{"id":"6052d543-c303-423b-94c4-56d39cac2525","subtype":"Chart","type":"Plot"}},"id":"da5c14bd-cc70-4ef8-bd20-0b4d1c45e92e","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"771642b6-95d5-4aa6-bf11-44692f5eeadf","type":"LinearAxis"}],"css_classes":null,"height":400,"left":[{"id":"4c2dcc81-5ba5-457c-a612-e520a660cc3a","type":"LinearAxis"}],"renderers":[{"id":"400dfef6-ce41-43bb-b866-f4a65f90ffde","type":"BoxAnnotation"},{"id":"b7c1a521-1b23-4432-81b6-cb7d1ef6f4c5","type":"GlyphRenderer"},{"id":"951fcc63-220c-4733-888b-1c930312d39d","type":"Legend"},{"id":"771642b6-95d5-4aa6-bf11-44692f5eeadf","type":"LinearAxis"},{"id":"4c2dcc81-5ba5-457c-a612-e520a660cc3a","type":"LinearAxis"},{"id":"f792fec8-d662-4206-a865-05 ...

# %% [markdown]
# ### Least Squares the way your _crazy uncle Eddie_ does it...
#
# ...'cause he used to work at NASA and code in Forth.

# %% [markdown]
# [`cvxopt`](http://cvxopt.org/) provides a [`qp`](http://cvxopt.org/userguide/coneprog.html#quadratic-programming) method that can solve anything of this form.
#
# $$
# \begin{align}
#     \text{min}  \ \ \ & \ \frac{1}{2} \beta'P\beta + q'\beta \\
#                       & \\
#     \text{s.t.} \ \ \ & \ G\beta \preceq h \\
#                       & \\
#                       & \ A\beta = b
# \end{align}
# $$

# %% [markdown]
# So we need to convert from
#
# $$\frac{1}{2} \beta'X'X\beta - y'X\beta + \frac{1}{2} y'y $$
#
# to another form
#
# $$\frac{1}{2} \beta'P\beta + q'\beta$$

# %% [markdown]
# which is simply
#
# $$P = X'X, q = -y$$

# %%
import cvxopt as cvx

P = cvx.matrix(np.matmul(Xt, X))
q = cvx.matrix(-1 * np.matmul(y.transpose(), X))
solution = cvx.solvers.qp(P, q)
beta = solution['x'] # unrelated to our x
print(beta)
# Out:
# [ 2.97e+00]
# [-2.29e+00]
# [ 1.06e+01]

# %%
# How'd Crazy Uncle Eddie do?
y_hat = [beta[0]*xi**2 + beta[1]*xi + beta[2] for xi in x]
show(Line({'x': x, 'y': y_hat}, x='x', y='y', width=750, height=400))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7961aad4-d46a-40d3-9a6e-d4c02ebc1194"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7961aad4-d46a-40d3-9a6e-d4c02ebc1194").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7961aad4-d46a-40d3-9a6e-d4c02ebc1194");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7961aad4-d46a-40d3-9a6e-d4c02ebc1194' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2388c812-0d99-4176-ac14-018fe38619ff":{"roots":{"references":[{"attributes":{"axis_label":"y","formatter":{"id":"9438582a-8aa2-48a3-8baa-7b0d9e12fdf7","type":"BasicTickFormatter"},"plot":{"id":"0bfee3f7-d907-4e94-8ce2-26f83865b300","subtype":"Chart","type":"Plot"},"ticker":{"id":"50010379-dbc0-4fdc-b17c-d140f35d9ea3","type":"BasicTicker"}},"id":"11efc1bf-2513-4631-b587-0a4ecdc44a63","type":"LinearAxis"},{"attributes":{"axis_label":"x","formatter":{"id":"6b459971-1f4d-4a1c-abae-5f28c3b44d54","type":"BasicTickFormatter"},"plot":{"id":"0bfee3f7-d907-4e94-8ce2-26f83865b300","subtype":"Chart","type":"Plot"},"ticker":{"id":"332c61fd-4b35-40fd-a082-09058b3c2eef","type":"BasicTicker"}},"id":"7fb4a6cd-9764-4d58-bebf-9cc97b9945b2","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1a32cbd3-0ae7-4fbd-9688-e9221a022474","type":"PanTool"},{"id":"d1c83cbf-8898-4ee9-bac5-ebc48f0caceb","type":"WheelZoomTool"},{"id":"e5c87b26-af70-4a13-b5a4-40aaa8c4f9a1","type":"BoxZoomTool"},{"id":"520a058d-8cbc-4e9c-bee1-668b3b5087bb","type":"SaveTool"},{"id":"b3974e95-d38a-4283-abc0-cad3628f8e80","type":"ResetTool"},{"id":"4644b6ff-de88-4a7e-9cfe-9d5d6608f99c","type":"HelpTool"}]},"id":"b0606bc3-d8fd-4156-86c3-e2284c4f4463","type":"Toolbar"},{"attributes":{},"id":"332c61fd-4b35-40fd-a082-09058b3c2eef","type":"BasicTicker"},{"attributes":{},"id":"6b459971-1f4d-4a1c-abae-5f28c3b44d54","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"0bfee3f7-d907-4e94-8ce2-26f83865b300","subtype":"Chart","type":"Plot"},"ticker":{"id":"332c61fd-4b35-40fd-a082-09058b3c2eef","type":"BasicTicker"}},"id":"e4061189-f0c2-4296-ac8d-58eecc350a7f","type":"Grid"},{"attributes":{},"id":"50010379-dbc0-4fdc-b17c-d140f35d9ea3","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"0bfee3f7-d907-4e94-8ce2-26f83865b300","subtype":"Chart","type":"Plot"},"ticker":{"id":"50010379-dbc0-4fdc-b17c-d140f35d9ea3","type":"BasicTicker"}},"id":"6a41a96f-b890-4629-9714-586c2fdadf2f","type":"Grid"},{"attributes":{"below":[{"id":"7fb4a6cd-9764-4d58-bebf-9cc97b9945b2","type":"LinearAxis"}],"css_classes":null,"height":400,"left":[{"id":"11efc1bf-2513-4631-b587-0a4ecdc44a63","type":"LinearAxis"}],"renderers":[{"id":"4e5ffc59-967c-48df-8a90-eb0f1aeb4e25","type":"BoxAnnotation"},{"id":"b671265e-0b56-44fa-905a-55ec161e8f24","type":"GlyphRenderer"},{"id":"64b5f43e-28f9-4aa3-bc9a-d3b2d60be1d4","type":"Legend"},{"id":"7fb4a6cd-9764-4d58-bebf-9cc97b9945b2","type":"LinearAxis"},{"id":"11efc1bf-2513-4631-b587-0a4ecdc44a63","type":"LinearAxis"},{"id":"e4061189-f0c2-4296-ac8d-58eecc350a7f","type":"Grid"},{"id":"6a41a96f-b890-4629-9714-586c2fdadf2f","type":"Grid"}],"title":{"id":"e6fd52ed-9edc-4159-9f1e-dfaec6dbdf99","type":"Title"},"tool_events":{"id":"b1d4a2f3-0b84-4153-8b81-ba06e40d6173","type":"ToolEvents"},"toolbar":{"id":"b0606bc3-d8fd-4156-86c3-e2284c4f4463","type":"Toolbar"},"width":750,"x_mapper_type":"auto","x_range":{"id":"468dbd34-c3e0-42af-b2b6-0e7dd68ce363","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"e9bf90d2-29dc-4977-bbb1-e9bc124b147e","type":"Range1d"}},"id":"0bfee3f7-d907-4e94-8ce2-26f83865b300","subtype":"Chart","type":"Plot"},{"attributes":{},"id":"9438582a-8aa2-48a3-8baa-7b0d9e12fdf7","type":"BasicTickFormatter"},{"attributes":{},"id":"b1d4a2f3-0b84-4153-8b81-ba06e40d6173","type":"ToolEvents"},{"attributes":{"plot":null,"text":null},"id":"e6fd52ed-9edc-4159-9f1e-dfaec6dbdf99","type":"Title"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null ...

# %% [markdown]
# #### So what's different about Crazy Uncle Eddie?

# %% [markdown]
# Well, besides the obvious.
#
# ![](images/crazy-uncle-eddie.jpg)

# %% [markdown]
# While all three techniques produced the _same result_, Crazy Uncle Eddie's is interesting because it is more general than the others.
#
# Crazy Eddie can solve any quadratic optimization problem, of which Least Squares is _just one instance_.

# %% [markdown]
# If we change the structure of the problem slightly:
#
# * We probably can't solve it with `scikit-learn`
# * Grams and Gramps have to go back to their chalkboard
# * Crazy Eddie can update the inputs to his problem and reoptimize

# %% [markdown]
# ## Example: Portfolio Optimization
#
# We have a big pot of money to allocate among different investments. Lucky us!

# %% [markdown]
# Some investment returns are correlated. They go up and down together.
#
# Other returns are anticorrelated. They tend to do the opposite things.

# %% [markdown]
# How do we allocate our money to maximize our expected return, subject to our tolerance for risk?

# %% [markdown]
# We'll use 100 months of [exchange rate data](http://www.federalreserve.gov/datadownload/Build.aspx?rel=H10) from the Fed, circa 2014.
#
# Since this talk isn't about data wrangling, I've already cleaned it up into the important pieces.
#
# * Expected monthly return data for each foreign currency
# * A covariance matrix for those investments

# %% [markdown]
# ### The Markowitz Porfolio Optimization Model
#
# #### Inputs:
#
# $$\mu = \text{vector of expected investment returns}$$
#
# $$\Sigma = \text{covariance matrix for returns}$$
#
# $$\alpha = \text{unitless measure of risk aversion}$$

# %% [markdown]
# #### Model:
#
# $x$ tells me how much of my total budget to put in each investment.
#
# $$
# \begin{align}
#     \text{max}  \ \ \ & \ \mu'x - \alpha x \Sigma x \\
#     \text{s.t.} \ \ \ & \ e'x = 1 \\
#                       & \ x \ge 0
# \end{align}
# $$

# %% [markdown]
# This may look more familiar.
#
# $$
# \begin{align}
#     \text{min}  \ \ \ & \ \alpha x \Sigma x - \mu'x \\
#     \text{s.t.} \ \ \ & \ e'x = 1 \\
#                       & \ x \ge 0
# \end{align}
# $$

# %% [markdown]
# The only differences between this model and the least squares model are the constraints we've added.
#
# This one forces the model to allocate all of my budget into investments:
#
# $$e'x = 1$$
#
# This one disallows the model from making negative investments:
#
# $$x \ge 0$$

# %% [markdown]
# But wait! This is a _maximization_ problem! The last model used $\text{min}$.

# %%
# Read in the returns and covariance data.
import pandas as pd
exp_returns = pd.read_csv('portfolio-optimization/currency-returns.csv')
exp_returns.head()
# Out:
#       Unnamed: 0      mean   variance
# 0  RXI$US_N.M.AL  0.152151  10.996718
# 1  RXI$US_N.M.EU  0.002683   5.928188
# 2  RXI$US_N.M.NZ  0.220217   9.690793
# 3  RXI$US_N.M.UK -0.159779   5.098969
# 4     RXI_N.M.BZ -0.128507  12.743632

# %%
returns_cov = pd.read_csv('portfolio-optimization/currency-covariance.csv', header=None)
returns_cov.head()
# Out:
#           0         1         2         3          4         5         6   \
# 0  10.996718  5.181782  8.654762  4.457704   9.789818  5.421746  0.194428
# 1   5.181782  5.928188  4.487890  3.659548   4.686754  2.467804  0.313081
# 2   8.654762  4.487890  9.690793  4.330531   8.130412  4.268307  0.129303
# 3   4.457704  3.659548  4.330531  5.098969   4.301933  2.573100  0.137068
# 4   9.789818  4.686754  8.130412  4.301933  12.743632  5.433992  0.279201
#
#          7         8         9     ...           13        14        15  \
# 0  5.166875  0.028496  4.379632    ...     6.494732  7.078498  7.083824
# 1  5.867674  0.038117  2.545200    ...     2.894461  5.350733  5.515164
# 2  4.466514  0.017975  3.919170    ...     5.536301  5.602586  6.054567
# 3  3.632088  0.012420  1.821456    ...     2.775715  4.081803  4.233658
# 4  4.689891 -0.034405  5.567318    ...     7.177333  7.288341  6.774689
#
#          16        17        18        19        20        21        22
# 0  8.574515  3.287411  0.343673  4.163674  2.450772  2.381722  0.542450
# 1  4.314480  2.265781  0.418269  5.173168  1.559857  1.351946  1.776855
# 2  6.733828  2.811946  0.451742  3.903260  2.135899  2.569281  0.379954
# 3  3.749874  1.780620  0.326828  3.335175  1.356927  1.014109  1.584577
# 4  8.761299  2.999360  0.843294  4.269524  2.163251  2.439204  0.496304
#
# [5 rows x 23 columns]

# %%
# A model that will return an optimal portfolio for any risk aversion.
def portfolio(alpha):
    P = cvx.matrix(alpha * returns_cov.as_matrix())
    q = cvx.matrix(-exp_returns['mean'].as_matrix())
    G = cvx.matrix(0.0, (len(q),len(q)))
    G[::len(q)+1] = -1.0
    h = cvx.matrix(0.0, (len(q),1))
    A = cvx.matrix(1.0, (1,len(q)))
    b = cvx.matrix(1.0)

    solution = cvx.solvers.qp(P, q, G, h, A, b)
    return exp_returns['mean'].dot(solution['x'])[0]

# %%
risk_aversion = [ra/2.0 for ra in range(41)]
returns = [portfolio(alpha) for alpha in risk_aversion]
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -1.4109e+00 -1.2870e+00  6e+01  9e+00  5e+00
#  1: -1.8207e-02 -1.2285e+00  1e+00  5e-15  8e-16
#  2: -6.2411e-02 -2.9637e-01  2e-01  7e-16  7e-16
#  3: -1.4238e-01 -3.5309e-01  2e-01  8e-16  5e-16
#  4: -2.8201e-01 -2.9496e-01  1e-02  4e-16  5e-16
#  5: -2.8688e-01 -2.8703e-01  2e-04  1e-16  3e-16
#  6: -2.8695e-01 -2.8695e-01  2e-06  3e-16  2e-16
#  7: -2.8695e-01 -2.8695e-01  2e-08  1e-16  5e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -2.6295e-01 -1.3019e+00  4e+01  5e+00  6e+00
#  1: -3.1048e-02 -1.0159e+00  2e+00  2e-01  2e-01
#  2:  3.3465e-02 -3.1889e-01  5e-01  3e-02  3e-02
#  3: -1.3476e-01 -2.5385e-01  1e-01  2e-17  5e-16
#  4: -1.9154e-01 -2.0318e-01  1e-02  2e-16  6e-16
#  5: -2.0001e-01 -2.0086e-01  9e-04  2e-16  5e-16
#  6: -2.0070e-01 -2.0074e-01  4e-05  1e-16  8e-16
#  7: -2.0073e-01 -2.0073e-01  1e-06  2e-16  1e-15
#  8: -2.0073e-01 -2.0073e-01  1e-08  1e-16  3e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -1.7310e-01 -1.2428e+00  4e+01  5e+00  6e+00
#  1: -4.7542e-03 -9.2263e-01  2e+00  2e-01  2e-01
#  2:  3.8252e-02 -2.6797e-01  4e-01  3e-02  3e-02
#  3: -9.4620e-02 -1.8481e-01  9e-02  1e-16  1e-15
#  4: -1.4057e-01 -1.5061e-01  1e-02  3e-16  5e-16
#  5: -1.4747e-01 -1.4833e-01  9e-04  1e-16  6e-16
#  6: -1.4822e-01 -1.4825e-01  3e-05  1e-16  5e-16
#  7: -1.4825e-01 -1.4825e-01  1e-06  2e-16  4e-16
#  8: -1.4825e-01 -1.4825e-01  2e-08  2e-16  5e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -1
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0:  9.8346e-02 -1.0343e+00  4e+01  5e+00  7e+00
#  1:  1.5019e-01 -4.7542e-01  2e+00  1e-01  2e-01
#  2:  1.2243e-01  2.2073e-02  2e-01  1e-02  2e-02
#  3:  1.1404e-01  9.3364e-02  2e-02  4e-05  6e-05
#  4:  1.0576e-01  1.0384e-01  2e-03  1e-06  2e-06
#  5:  1.0440e-01  1.0429e-01  1e-04  7e-09  1e-08
#  6:  1.0431e-01  1.0431e-01  1e-06  7e-11  9e-11
#  7:  1.0431e-01  1.0431e-01  1e-08  7e-13  9e-13
# Optimal solution found.

# %%
show(Line(
    {'risk aversion': risk_aversion, 'expected return': returns}, 
    x='risk aversion', 
    y='expected return', 
    width=750, 
    height=400
))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="36cb2b1d-0dbd-4542-9340-8aa562c7b5ed"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("36cb2b1d-0dbd-4542-9340-8aa562c7b5ed").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("36cb2b1d-0dbd-4542-9340-8aa562c7b5ed");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '36cb2b1d-0dbd-4542-9340-8aa562c7b5ed' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4edcafd6-65b9-46fa-abca-70a4d2e6d2bc":{"roots":{"references":[{"attributes":{"axis_label":"risk aversion","formatter":{"id":"c765f434-c0f9-43e3-be80-16df2ebbb36d","type":"BasicTickFormatter"},"plot":{"id":"4eb7959d-e7f4-4297-b0cf-96a8219b86e8","subtype":"Chart","type":"Plot"},"ticker":{"id":"0e7ecb10-b5b8-4d12-bb54-1b252739f991","type":"BasicTicker"}},"id":"e20f934c-aa23-48ef-a469-d93e76de969a","type":"LinearAxis"},{"attributes":{"plot":{"id":"4eb7959d-e7f4-4297-b0cf-96a8219b86e8","subtype":"Chart","type":"Plot"},"ticker":{"id":"0e7ecb10-b5b8-4d12-bb54-1b252739f991","type":"BasicTicker"}},"id":"7b365a8c-5519-412a-985d-2ffb6693eda0","type":"Grid"},{"attributes":{},"id":"1de07787-0a3b-47bf-819f-0930d3751720","type":"BasicTicker"},{"attributes":{"plot":{"id":"4eb7959d-e7f4-4297-b0cf-96a8219b86e8","subtype":"Chart","type":"Plot"}},"id":"4b49b031-0292-4e1d-b0ae-6ee025e6e112","type":"HelpTool"},{"attributes":{},"id":"a90a7b81-43c8-4e41-a032-0b438bb689d9","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"eba03e8d-d639-409d-bcc7-95d0e3d36ca9","type":"BoxAnnotation"},"plot":{"id":"4eb7959d-e7f4-4297-b0cf-96a8219b86e8","subtype":"Chart","type":"Plot"}},"id":"1d8798fe-af16-4213-9576-d1a49ac0dee9","type":"BoxZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"4eb7959d-e7f4-4297-b0cf-96a8219b86e8","subtype":"Chart","type":"Plot"},"ticker":{"id":"1de07787-0a3b-47bf-819f-0930d3751720","type":"BasicTicker"}},"id":"362bf695-e598-402a-b193-1936d9dca66e","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a9bf9b66-42bb-440f-9a71-832a6e49ac4d","type":"PanTool"},{"id":"2d7cc2b3-b697-40c1-8172-29478e4213dc","type":"WheelZoomTool"},{"id":"1d8798fe-af16-4213-9576-d1a49ac0dee9","type":"BoxZoomTool"},{"id":"8ca975bf-34d9-4f27-89c5-68fa9243af74","type":"SaveTool"},{"id":"20510c91-0a9a-4d3d-b6f3-3b9f8a54cc94","type":"ResetTool"},{"id":"4b49b031-0292-4e1d-b0ae-6ee025e6e112","type":"HelpTool"}]},"id":"7405dc79-5395-4038-b412-db11d6ce9310","type":"Toolbar"},{"attributes":{"plot":{"id":"4eb7959d-e7f4-4297-b0cf-96a8219b86e8","subtype":"Chart","type":"Plot"}},"id":"2d7cc2b3-b697-40c1-8172-29478e4213dc","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":null},"id":"df76c3e8-7894-44ce-bf78-2b46191b3c1c","type":"Title"},{"attributes":{"plot":{"id":"4eb7959d-e7f4-4297-b0cf-96a8219b86e8","subtype":"Chart","type":"Plot"}},"id":"a9bf9b66-42bb-440f-9a71-832a6e49ac4d","type":"PanTool"},{"attributes":{"data_source":{"id":"3d2f3d8d-0f2e-4eb5-aa19-8c8d2ea84cde","type":"ColumnDataSource"},"glyph":{"id":"f3e20dff-cba4-4723-b43e-daae98728b79","type":"Line"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"ab6179c3-6017-4b36-ae23-d0f138132e40","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":{"__ndarray__":"...","dtype":"float64","shape":[41]},"y_values":{"__ndarray__":"...","dtype":"float64","shape":[41]}}},"id":"3d2f3d8d-0f2e-4eb5-aa19-8c8d2ea84cde","type":"ColumnDataSource"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"eba03e8d-d639-409d-bcc7-95d0e3d36ca9","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":22.0,"start":-2.0},"id":"57ad6594-5de9-4f0a-b3b6-37b8a66c3121","type":"Range1d"},{"attributes":{"axis_label":"expected return","formatter":{"id":"a90a7b81-43c8-4e41-a032-0b438bb689d9","type":"BasicTickFormatter"},"plot":{"id":"4eb7959d-e7f4-4297-b0cf-96a8219b86e8","subtype":" ...

# %% [markdown]
# ## Support Vector Machines
#
# We want to draw a line that separates two sets with as little misclassification as possible.

# %% [markdown]
# If $f(x) \le 5$, the point is of type $-1$, otherwise it is type $+1$.
#
# $$f(x) = (x_1 + \epsilon_1) - (x_2+ \epsilon_2)$$
#
# $$\epsilon_i \sim N\left(0, 1.25^2\right)\ \forall\ i \in {1, 2}$$

# %%
x1 = [random.uniform(0, 10) for _ in range(150)]
x2 = [random.uniform(0, 10) for _ in range(150)]

y = []
for xi_1, xi_2 in zip(x1, x2):
    eps_1 = random.normalvariate(0, 1.25)
    eps_2 = random.normalvariate(0, 1.25)
    
    if (xi_1 + eps_1) - (xi_2 + eps_2) <= 5:
        y.append(-1)
    else:
        y.append(+1)
        
X = np.array(list(zip(x1, x2)))
y = np.array(y)

# %%
show(Scatter(
    {'x1': x1, 'x2': x2, 'y': y}, 
    x='x1', y='x2', color='y', marker='y', palette=['lightblue', 'orange'],
    width=750, height=400
))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id
ers":[{"id":"d10b62f4-160d-452b-83a7-0b32e11f2cd7","type":"GlyphRenderer"}]},"id":"eca7368e-8476-4370-9659-de904fc4436c","type":"LegendItem"},{"attributes":{"plot":{"id":"fab11768-5a1b-41b6-be26-800ec51ecc8a","subtype":"Chart","type":"Plot"}},"id":"ae0f0359-e479-4002-bf05-2abcbd0a75ad","type":"WheelZoomTool"},{"attributes":{},"id":"145c79de-105f-43ba-9162-7dd5a94dbcf2","type":"BasicTickFormatter"},{"attributes":{},"id":"9df1cf9f-f343-4785-bf2b-7197ef39b447","type":"BasicTicker"},{"attributes":{},"id":"00b5137f-bd3c-4c5a-9f8c-4e122d6634a8","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"fab11768-5a1b-41b ...

# %% [markdown]
# ### Support Vector Machines a la `scikit-learn`

# %%
from sklearn import metrics, svm
clf = svm.SVC(kernel='linear')
clf.fit(X, y)

y_hat = clf.predict(X)

print('coefficients:', clf.intercept_, clf.coef_)
print('confusion matrix:')
metrics.confusion_matrix(y_true=y, y_pred=y_hat)
# Out:
# coefficients: [-2.53047237] [[ 0.61340886 -0.65958552]]
# confusion matrix:
# array([[117,   4],
#        [  6,  23]])

# %%
correct = ['Correct' if yi == yh_i else 'Incorrect' for yi, yh_i in zip(y, y_hat)]
show(Scatter(
    {'x1': x1, 'x2': x2, 'y': y, 'correct': correct}, 
    x='x1', y='x2', color='correct', palette=['lightgrey', 'darkred'], marker='correct',
    width=750, height=400
))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="dec0db4d-4f4e-4ed8-8c1a-0179dc4939e5"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("dec0db4d-4f4e-4ed8-8c1a-0179dc4939e5").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("dec0db4d-4f4e-4ed8-8c1a-0179dc4939e5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'dec0db4d-4f4e-4ed8-8c1a-0179dc4939e5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6bbf3e5a-02ec-415d-92ad-fac92eb17876":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"21136e6e-629b-4e13-9c62-73b68e30f6ca","subtype":"Chart","type":"Plot"},"ticker":{"id":"83cd4caf-c0cb-43a4-81b8-eb839e53719a","type":"BasicTicker"}},"id":"8d2b17e4-abd8-47fc-bbac-9a889465359f","type":"Grid"},{"attributes":{},"id":"d99a5cb3-927f-4340-8c3d-70e48f5c0d50","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"32fb6465-146f-4a47-96b1-9da981502071","type":"BoxAnnotation"},"plot":{"id":"21136e6e-629b-4e13-9c62-73b68e30f6ca","subtype":"Chart","type":"Plot"}},"id":"d617511b-f7cd-427e-b50e-7ee8c992704b","type":"BoxZoomTool"},{"attributes":{"label":{"value":"Incorrect"},"renderers":[{"id":"6e5c61e4-8739-4bb2-8a9f-5ac08f32a018","type":"GlyphRenderer"}]},"id":"aa6fe2cc-7ae8-4ae5-8814-98cfdce0dd07","type":"LegendItem"},{"attributes":{"plot":{"id":"21136e6e-629b-4e13-9c62-73b68e30f6ca","subtype":"Chart","type":"Plot"},"ticker":{"id":"10eb4a3d-5e96-49f9-9d4b-baf9ea2fee6f","type":"BasicTicker"}},"id":"4eb77fba-d32d-4739-93ea-49f1b1ecc81f","type":"Grid"},{"attributes":{"label":{"value":"Correct"},"renderers":[{"id":"467b3f2d-a9f4-4d00-b47f-b89f0270c6fb","type":"GlyphRenderer"}]},"id":"f1b3f0f6-ae23-4000-979f-e93a4e9ee556","type":"LegendItem"},{"attributes":{"items":[{"id":"f1b3f0f6-ae23-4000-979f-e93a4e9ee556","type":"LegendItem"},{"id":"aa6fe2cc-7ae8-4ae5-8814-98cfdce0dd07","type":"LegendItem"}],"location":"top_left","plot":{"id":"21136e6e-629b-4e13-9c62-73b68e30f6ca","subtype":"Chart","type":"Plot"}},"id":"16c4046b-4c86-4af0-b916-29d9ac4d989a","type":"Legend"},{"attributes":{"axis_label":"x1","formatter":{"id":"d99a5cb3-927f-4340-8c3d-70e48f5c0d50","type":"BasicTickFormatter"},"plot":{"id":"21136e6e-629b-4e13-9c62-73b68e30f6ca","subtype":"Chart","type":"Plot"},"ticker":{"id":"10eb4a3d-5e96-49f9-9d4b-baf9ea2fee6f","type":"BasicTicker"}},"id":"fd776477-e64a-429e-8511-ba30e3cef4cb","type":"LinearAxis"},{"attributes":{"plot":{"id":"21136e6e-629b-4e13-9c62-73b68e30f6ca","subtype":"Chart","type":"Plot"}},"id":"36a23f4f-f22b-4eee-84c4-e18c36d1ce8b","type":"HelpTool"},{"attributes":{"axis_label":"x2","formatter":{"id":"01fc6abe-ae30-4cc5-858f-e7efcba34f93","type":"BasicTickFormatter"},"plot":{"id":"21136e6e-629b-4e13-9c62-73b68e30f6ca","subtype":"Chart","type":"Plot"},"ticker":{"id":"83cd4caf-c0cb-43a4-81b8-eb839e53719a","type":"BasicTicker"}},"id":"dc06c661-5dff-4b73-ad69-7988af69f595","type":"LinearAxis"},{"attributes":{},"id":"83cd4caf-c0cb-43a4-81b8-eb839e53719a","type":"BasicTicker"},{"attributes":{"below":[{"id":"fd776477-e64a-429e-8511-ba30e3cef4cb","type":"LinearAxis"}],"css_classes":null,"height":400,"left":[{"id":"dc06c661-5dff-4b73-ad69-7988af69f595","type":"LinearAxis"}],"renderers":[{"id":"32fb6465-146f-4a47-96b1-9da981502071","type":"BoxAnnotation"},{"id":"467b3f2d-a9f4-4d00-b47f-b89f0270c6fb","type":"GlyphRenderer"},{"id":"6e5c61e4-8739-4bb2-8a9f-5ac08f32a018","type":"GlyphRenderer"},{"id":"16c4046b-4c86-4af0-b916-29d9ac4d989a","type":"Legend"},{"id":"fd776477-e64a-429e-8511-ba30e3cef4cb","type":"LinearAxis"},{"id":"dc06c661-5dff-4b73-ad69-7988af69f595","type":"LinearAxis"},{"id":"4eb77fba-d32d-4739-93ea-49f1b1ecc81f","type":"Grid"},{"id":"8d2b17e4-abd8-47fc-bbac-9a889465359f","type":"Grid"}],"title":{"id":"bdc8338d-678c-41f1-be4f-dd1fbdd311d6","type":"Title"},"tool_events":{"id":"fbe1d892-b0ef-4f4c-88a7-3fe38a29ca5c","type":"ToolEvents"},"toolbar":{"id":"ec619968-2ca4-4930-9167-3f73871b7301","type":"Toolbar"},"width":750,"x_mapper_type":"auto","x_range":{"id":"b813c0f3-f2b3-4ef4-9103-b5f063d116e9","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"22897ff9-1cb7-48c8-8f3e-f339174db8b5","type":"Range1d"}},"id":"21136e6e-629b-4e13-9c62-73b68e30f6ca","subtype":"Chart","type":"Plot"},{"attributes":{"plot":{"id":"21136e6e-629b-4e13-9c62-73b68e30f6ca","subtype":"Chart","type":"Plot"}},"id":"a228071b-4578-442d-8ad4-85eb7603085a","type":"ResetTool"},{"attributes":{"plot":{"id":"2113 ...

# %%
### Support Vector Machines a la Linear Optimization

# %%
import pulp

m = pulp.LpProblem(sense=pulp.LpMinimize)

w1 = pulp.LpVariable('w1')
w2 = pulp.LpVariable('w2')
b = pulp.LpVariable('b')

errors = []
for i, (xi_1, xi_2, y_i) in enumerate(zip(x1, x2, y)):
    e = pulp.LpVariable('e_%d' % (i+1), lowBound=0)
    m += y_i * (w1 * xi_1 + w2 * xi_2 + b) >= (1 - e)
    errors.append(e)
    
m.setObjective(sum(errors))
assert m.solve() == pulp.LpStatusOptimal

def classify(xi_1, xi_2):
    foo = w1.value() * xi_1 + w2.value() * xi_2 + b.value() >= 0
    return 1 if foo else -1

y_hat = [classify(xi_1, xi_2) for xi_1, xi_2 in zip(x1, x2)]

print('coefficients:', b.value(), w1.value(), w2.value())
print('confusion matrix:')
metrics.confusion_matrix(y_true=y, y_pred=y_hat)
# Out:
# coefficients: -2.7841666 0.65345083 -0.67781657
# confusion matrix:
# array([[117,   4],
#        [  6,  23]])

# %%
correct = ['Correct' if yi == yh_i else 'Incorrect' for yi, yh_i in zip(y, y_hat)]
plot = Scatter(
    {'x1': x1, 'x2': x2, 'y': y, 'correct': correct}, 
    x='x1', y='x2', color='correct', palette=['lightgrey', 'darkred'], marker='correct',
    width=750, height=400
)

svm_x1 = np.linspace(0, 10)
svm_x2 = [(b.value() - (w1.value() * x1_i)) / w2.value() for x1_i in svm_x1]
plot.line(svm_x2, svm_x1)
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f9bdfc14-cd5f-4988-adc2-b0192f80153b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("f9bdfc14-cd5f-4988-adc2-b0192f80153b").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f9bdfc14-cd5f-4988-adc2-b0192f80153b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f9bdfc14-cd5f-4988-adc2-b0192f80153b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"5197a3b3-0694-475e-8841-6f9dade3c128":{"roots":{"references":[{"attributes":{"plot":{"id":"9f9d5690-d33e-45ea-b930-148a5b949ca1","subtype":"Chart","type":"Plot"}},"id":"1ef33c40-a984-4abf-b90e-69aaef337cae","type":"SaveTool"},{"attributes":{},"id":"4740cd22-1cb7-404a-9312-b2a6cfa3892a","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"9f9d5690-d33e-45ea-b930-148a5b949ca1","subtype":"Chart","type":"Plot"},"ticker":{"id":"12974205-3cfe-4873-bbdc-8d05b294a868","type":"BasicTicker"}},"id":"1d2df4e4-3c15-42f6-8e35-345240fd147b","type":"Grid"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{